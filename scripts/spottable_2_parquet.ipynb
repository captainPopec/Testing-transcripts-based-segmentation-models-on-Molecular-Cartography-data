# %%
import tifffile as tiff
import numpy as np
import geopandas as gpd
from shapely.geometry import shape, MultiPolygon
from rasterio.features import shapes
import pandas as pd
from collections import defaultdict

# %% [markdown]
# shema: x, y, z, gene, tile_x, tile_y, tile_z, roi_id, slide_id

# %% [markdown]
# Definicija funckije

# %%
def txt2parquet(sample_id, segmentation_mask, spots_path, output_dir):
    import pandas as pd
    import numpy as np
    import tifffile
    from pathlib import Path
    import glob
    
    mask_np = tifffile.imread(segmentation_mask) # loads full image into memory - not perfect, but works for this case

    print('loaded mask')
    mask_bool = mask_np > 0

    spots = pd.read_csv(spots_path, sep='\t', header=None, )
    # drop all columns except first 4
    spots = spots.iloc[:, :4]
    spots.columns = ['global_x', 'global_y', 'global_z', 'gene']
    spots = spots[spots['gene'] != 'Duplicated']

    print('loaded spots')

    spots['overlaps_nucleus'] = mask_bool[spots['global_y'].astype(int), spots['global_x'].astype(int)]
    spots['transcript_id'] = np.arange(len(spots))
    spots['cell_id'] = mask_np[spots['global_y'].astype(int), spots['global_x'].astype(int)]
    spots['cell_id'] = spots['cell_id'].replace(0, -1)
    spots['EntityID'] = spots['cell_id'].copy() # needed yes/no??
    spots.to_parquet(f'{output_dir}/{sample_id}/transcripts.parquet', index=False)
    print(f"Saved Parquet for sample {sample_id}")

# %% [markdown]
# Main script for running the function

# %%
from pathlib import Path
import glob
import os

path_table = pd.read_csv("/home/davids/main/sds/sd22c003/mi_spatialomics_project/MI_ApoE/Molecular_Cartography/cellposesam_segger_sample_overview.csv")
output_dir = "/home/davids/main/projects/Segger_final/input_for_segger"

for spots in path_table.spot_table:
    sample_ID = Path(spots).stem.split('_results')[0]
    beast_spots_path = spots.replace("$HOME/sds-hd/", "/home/davids/main/sds/")

    #searching for Mask file
    pattern = os.path.join("/home/davids/main/sds/sd22c003/mi_spatialomics_project/MI_ApoE/Molecular_Cartography/cpsam_segmentations", f"{sample_ID}*.tif")
    mask = glob.glob(pattern)
    
    #print(f"Processing sample: {sample_ID}")
    txt2parquet(sample_ID, mask, beast_spots_path, output_dir)
# Out:
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-1_A1-1
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-1_A2-2
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-1_A2-3
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-1_B1-1
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-1_B1-2
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-1_B2-2
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-1_C2-1
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-1_D2-1
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-5_A1-2
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-5_A2-1
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-5_B1-3
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-5_B2-1
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-5_C1-1
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-5_C2-2
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-5_D1-2
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-22_A1-1
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-22_A2-1
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-22_B1-1
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-22_B2-1
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-22_C1-1
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-22_C2-1
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-22_D1-1
# loaded mask
# loaded mask
# loaded spots
# Saved Parquet for sample 33156-Slide-22_D2-1
